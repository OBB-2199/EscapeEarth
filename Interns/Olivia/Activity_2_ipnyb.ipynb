# %% [markdown]
# <a href="https://colab.research.google.com/github/OBB-2199/EscapeEarth/blob/main/Interns/Olivia/Activity_2_ipnyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
my_path = '/content/gdrive/My Drive/EscapeEarthData/Activity-2/'

df1 = pd.read_csv('{}df1.csv'.format(my_path))
df2 = pd.read_csv('{}df2.csv'.format(my_path))
df3 = pd.read_csv('{}df3.csv'.format(my_path))
df4 = pd.read_csv('{}df4.csv'.format(my_path))
df5 = pd.read_csv('{}df5.csv'.format(my_path))
df6 = pd.read_csv('{}df6.csv'.format(my_path))
df7 = pd.read_csv('{}df7.csv'.format(my_path))
df8 = pd.read_csv('{}df8.csv'.format(my_path))

# %%
plt.scatter(df1['col1'], df1['col2'], s = 0.5)

# %%
plt.scatter(df2['col1'], df2['col2'], s = 0.5)

# %%
plt.scatter(df3['col1'], df3['col2'], s = 0.5)

# %%
plt.scatter(df4['col1'], df4['col2'], s = 0.5)

# %%
plt.scatter(df5['col1'], df5['col2'], s = 0.5)

# %%
plt.scatter(df6['col1'], df6['col2'], s = 0.5)

# %%
plt.scatter(df7['col1'], df7['col2'], s = 0.5)

# %%
plt.scatter(df8['col1'], df8['col2'], s = 0.5)

# %%
plt.scatter(df1['col1'], df1['col2'], color = 'royalblue', s = 0.5)
plt.scatter(df2['col1'], df2['col2'], color = 'mediumorchid', s = 0.5)
plt.scatter(df3['col1'], df3['col2'], color = 'mediumseagreen', s = 0.5)
plt.scatter(df4['col1'], df4['col2'], color = 'darkorange', s = 0.5)
plt.scatter(df5['col1'], df5['col2'], color = 'gold', s = 0.5)
plt.scatter(df6['col1'], df6['col2'], color = 'tomato', s = 0.5)
plt.scatter(df7['col1'], df7['col2'], color = 'saddlebrown', s = 0.5)
plt.scatter(df8['col1'], df8['col2'], color = 'dimgray', s = 0.5)

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([df1['col1'].to_numpy()], [df1['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new = c_old.galactic
for count in range(len(c_new[0])):
        df1_new_col1 = c_new[0].l.degree
        df1_new_col2 = c_new[0].b.degree
new_data = {'col1':df1_new_col1,'col2':df1_new_col2}
df1_new = pd.DataFrame(new_data)

# %%
plt.scatter(df1_new['col1'], df1_new['col2'], color = 'royalblue', s = 0.5)

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([df2['col1'].to_numpy()], [df2['col2'].to_numpy()], frame='icrs',unit='degree')
c_new = c_old.galactic
for count in range(len(c_new[0])):
        df2_new_col1 = c_new[0].l.degree
        df2_new_col2 = c_new[0].b.degree
new_data = {'col1':df2_new_col1,'col2':df2_new_col2}
df2_new = pd.DataFrame(new_data)

# %%
plt.scatter(df2_new['col1'], df2_new['col2'], color = 'mediumorchid', s = 0.5)

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([df3['col1'].to_numpy()], [df3['col2'].to_numpy()], frame='icrs',unit='degree')
c_new = c_old.galactic
for count in range(len(c_new[0])):
        df3_new_col1 = c_new[0].l.degree
        df3_new_col2 = c_new[0].b.degree
new_data = {'col1':df3_new_col1,'col2':df3_new_col2}
df3_new = pd.DataFrame(new_data)

# %%
plt.scatter(df3_new['col1'], df3_new['col2'], color = 'mediumseagreen', s = 0.5)

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([df4['col1'].to_numpy()], [df4['col2'].to_numpy()], frame='icrs',unit='degree')
c_new = c_old.galactic
for count in range(len(c_new[0])):
        df4_new_col1 = c_new[0].l.degree
        df4_new_col2 = c_new[0].b.degree
new_data = {'col1':df4_new_col1,'col2':df4_new_col2}
df4_new = pd.DataFrame(new_data)

# %%
plt.scatter(df4_new['col1'], df4_new['col2'], color = 'darkorange', s = 0.5)

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([df5['col1'].to_numpy()], [df5['col2'].to_numpy()], frame='icrs',unit='degree')
c_new = c_old.galactic
for count in range(len(c_new[0])):
        df5_new_col1 = c_new[0].l.degree
        df5_new_col2 = c_new[0].b.degree
new_data = {'col1':df5_new_col1,'col2':df5_new_col2}
df5_new = pd.DataFrame(new_data)

# %%
plt.scatter(df5_new['col1'], df5_new['col2'], color = 'gold', s = 0.5)

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([df6['col1'].to_numpy()], [df6['col2'].to_numpy()], frame='icrs',unit='degree')
c_new = c_old.galactic
for count in range(len(c_new[0])):
        df6_new_col1 = c_new[0].l.degree
        df6_new_col2 = c_new[0].b.degree
new_data = {'col1':df6_new_col1,'col2':df6_new_col2}
df6_new = pd.DataFrame(new_data)

# %%
plt.scatter(df6_new['col1'], df6_new['col2'], color = 'tomato', s = 0.5)

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([df7['col1'].to_numpy()], [df7['col2'].to_numpy()], frame='icrs',unit='degree')
c_new = c_old.galactic
for count in range(len(c_new[0])):
        df7_new_col1 = c_new[0].l.degree
        df7_new_col2 = c_new[0].b.degree
new_data = {'col1':df7_new_col1,'col2':df7_new_col2}
df7_new = pd.DataFrame(new_data)

# %%
plt.scatter(df7_new['col1'], df7_new['col2'], color = 'saddlebrown', s = 0.5)

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([df8['col1'].to_numpy()], [df8['col2'].to_numpy()], frame='icrs',unit='degree')
c_new = c_old.galactic
for count in range(len(c_new[0])):
        df8_new_col1 = c_new[0].l.degree
        df8_new_col2 = c_new[0].b.degree
new_data = {'col1':df8_new_col1,'col2':df8_new_col2}
df8_new = pd.DataFrame(new_data)

# %%
plt.scatter(df8_new['col1'], df8_new['col2'], color = 'dimgray', s = 0.5)

# %%
plt.scatter(df1_new['col1'], df1_new['col2'], color = 'royalblue', s = 0.5)
plt.scatter(df2_new['col1'], df2_new['col2'], color = 'mediumorchid', s = 0.5)
plt.scatter(df3_new['col1'], df3_new['col2'], color = 'mediumseagreen', s = 0.5)
plt.scatter(df4_new['col1'], df4_new['col2'], color = 'darkorange', s = 0.5)
plt.scatter(df5_new['col1'], df5_new['col2'], color = 'gold', s = 0.5)
plt.scatter(df6_new['col1'], df6_new['col2'], color = 'tomato', s = 0.5)
plt.scatter(df7_new['col1'], df7_new['col2'], color = 'saddlebrown', s = 0.5)
plt.scatter(df8_new['col1'], df8_new['col2'], color = 'dimgray', s = 0.5)
